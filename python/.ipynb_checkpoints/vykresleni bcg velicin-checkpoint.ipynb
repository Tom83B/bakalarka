# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import ext_data as ext
from loadbcg import *
from const import *

#z=z[::-1]
#T=T[::-1]
#P=P[::-1]

# %%
sys.path.insert(1, os.getcwd()+'/opacity')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-ad8e55ba3773> in <module>()
# ----> 1 from OPAL.opacity import xzcotrin21
#
# /home/tom/Documents/skola/bakalarka/python/OPAL/opacity.py in <module>()
#       2 import sys
#       3 sys.path.insert(1, os.getcwd()+'/opacity')
# ----> 4 import xzcotrin21 as xz
#       5
#       6 xz.set_mol_dir('opacity/fergson/')
#
# ImportError: No module named xzcotrin21

# %%
fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=5000
axes.plot(z, 3.5*np.log(T)-R*np.log(P), c='black')
#axes.plot(z, S, c='blue')
#axes.plot(z, rho, c='black')
#axes.plot(P[m:n], T[0]*(P[m:n]/P[0])**(2./5), c='green')
#axes.plot(z[m:n], ext.T(z[m:n]), c='black', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
#axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
#axes.set_ylabel(r"$ T\ \mathrm{(K)} $",fontsize=18)

fig.savefig("S.png",bbox_inches='tight')

# %%
S-cv*np.log(P)-cp*np.log(rho)
# Out:
# array([ 354923.45975434,  352904.62685548,  351082.0719514 , ...,
#        -360158.06734087, -361098.74508124, -362047.37913987])

# %%
np.exp(9)
# Out:
# 8103.0839275753842

# %%
from scipy.interpolate import UnivariateSpline as interp
import derivatives as d
import EOS

frad = np.empty(z.size)
fconv = np.empty(z.size)
ftot = np.empty(z.size)
f = np.empty([z.size,3])
change = np.zeros(z.size)

for t in range(0,1):
    Tfunc = interp(z, T, s=0, k=3)
    dTdz = np.diff(T)/np.diff(z)
    dTdz = np.append(dTdz,dTdz[dTdz.size-1])
    Pfunc = interp(z, P, s=0, k=3)
    dPdz = Pfunc.derivative()

    for i in range(0,z.size):
        f[i] = d.flux(T[i], dTdz[i], P[i], dPdz(z[i]), z[i], 0.3)
        frad[i] = f[i,0]
        fconv[i] = f[i,1]
        ftot[i] = f[i,2]
        change[i] = 1./(EOS.rho(T[i],P[i],z[i])*EOS.cp(T[i],P[i],z[i]))

    change = change*np.append(np.diff(ftot)/np.diff(z),0.004)    
    #T = T+100000*change

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
#axes.plot(z[m:n], Frad(z[m:n])+Fconv(z[m:n]), c='green')
#axes.plot(z[m:n], F_bcg(z[m:n]), c='green', linestyle='dashed')
#axes.plot(z[m:n], -fconv[m:n]/ftot[m:n], c='green', label='fconv')
axes.plot(z[m:n], frad[m:n], c='red', label='frad')
#axes.plot(z[m:n], frad[m:n]-fconv[m:n], c='blue', label='fconv+frad')
#axes.plot(z[m:n], ftot[m:n], c='black', linestyle='dashed', label='ftot')
#axes.plot(z[m:n], dTdz(z[m:n]), c='red')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
axes.set_ylabel(r"$ \nabla_\mathrm{ad} $",fontsize=18)
axes.legend()

fig.savefig("frad.png",bbox_inches='tight')
# Out:
# -0.317084223438
# -0.320053511404
# -0.322907393254
# -0.325649431522
# -0.328289954308
# -0.330843030402
# -0.333325920908
# -0.335760528549
# -0.338170982203
# -0.340587573869
# -0.343029257884
# -0.345397264595
# -0.347642660575
# -0.349771501811
# -0.351795371959
# -0.353724638132
# -0.355575854515
# -0.3573681816
# -0.359120884328
# -0.36085846302
# -0.362595125905
# -0.364250043826
# -0.365797178504
# 205326.823053
# 203066.051282
# 200819.522258
# 198587.332782
# 196369.556041
# 194166.321077
# 191977.805698
# 189804.022852
# 187645.348068
# 185501.85839
# 183373.699311
# 181260.918371
# 179163.562022
# 177081.666236
# 175015.392056
# 172964.844195
# 170930.056043
# 168911.094675
# 166910.061213
# 164932.347234
# 162977.958956
# 161046.919726
# 159139.081754
# 157254.281897
# 155392.36283
# 153553.094508
# 151736.339314
# 149941.879618
# 148169.504853
# 146419.028094
# 144690.230126
# 142982.877055
# 141296.797467
# 139631.918158
# 137988.087473
# 136365.148896
# 134762.840345
# 133181.019328
# 131619.447992
# 130077.906618
# 128556.205652
# 127054.139351
# 125571.453898
# 124107.9893
# 122663.582499
# 121238.169625
# 119831.546079
# 118443.548451
# 117073.946715
# 115723.367646
# 114389.976
# 113074.413789
# 111776.495699
# 110496.122288
# 109233.059109
# 107987.190804
# 106758.393185
# 105546.425403
# 104351.12996
# 103172.271334
# 102009.633124
# 100863.026041
# 99732.2230965
# 98616.992525
# 97517.1410266
# 96432.4438476
# 95362.74614
# 94307.9108236
# 93267.7487569
# 92242.0724208
# 91230.6922935
# 90233.4338818
# 89250.0672305
# 88280.4400217
# 87324.3635258
# 86381.6275432
# 85452.1073579
# 84535.6991181
# 83632.215714
# 82741.4688151
# 81863.2915073
# 80997.4990371
# 80143.934683
# 79302.3721873
# 78472.6592174
# 77654.5740101
# 76847.6153501
# 76051.5289457
# 75266.1928502
# 74491.4939628
# 73727.2903975
# 72973.4433482
# 72229.8364021
# 71496.3227381
# 70772.7879818
# 70059.0952025
# 69355.1884592
# 68660.9636285
# 67976.2699135
# 67301.0144292
# 66635.0492823
# 65978.2433459
# 65330.4939012
# 64691.6423132
# 64061.5725926
# 63440.2236354
# 62827.4654981
# 62223.1985585
# 61627.2957847
# 61039.6399062
# 60460.0978729

# %%
import EOS

cp = np.empty(z.size)
cp_ext = np.empty(z.size)

for i in range(0,z.size):
    cp[i] = EOS.cp(T[i], P[i],z[i])
    cp_ext[i] = EOS.cp(ext.T(z[i]), ext.p(z[i]),z[i])

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(z[m:n], cp[m:n], c='black')
axes.plot(z[m:n], cp_ext[m:n], c='black', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
axes.set_ylabel(r"$ c_P $",fontsize=18)
#axes.legend()

fig.savefig("cp.png",bbox_inches='tight')

# %%
import EOS

rho = np.empty(z.size)
rho_ext = np.empty(z.size)
rho_ext_real = np.empty(z.size)

for i in range(0,z.size):
    rho[i] = EOS.rho(T[i], P[i], z[i])
    rho_ext[i] = EOS.rho(ext.T(z[i]), ext.p(z[i]), z[i])
    rho_ext_real[i] = ext.r(z[i])

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=5000
axes.plot(z[m:n], rho[m:n], c='black')
#axes.plot(z[m:n], rho_ext[m:n], c='black', linestyle = 'dashed')
axes.plot(z[m:n], rho_ext_real[m:n], c='red', linestyle = '-.')
#axes.plot(z[m:n], 1e-3*P[m:n]*EOS.mu(T[m:n],P[m:n])/(R*T[m:n]), c='blue')
#axes.plot(z[m:n], 1e-3*ext.p(z[m:n])*EOS.mu(ext.T(z[m:n]),ext.p(z[m:n]))/(R*ext.T(z[m:n])), c='blue', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
axes.set_ylabel(r"$ \rho\ (\mathrm{kg.m^{-3}}) $",fontsize=18)
#axes.legend()

fig.savefig("rho.png",bbox_inches='tight')

# %%
from scipy.interpolate import UnivariateSpline as interp
P_T = interp(T,P)
print P_T(ext.T(0))
print ext.p(0)
# Out:
# 9486.9018902
# 7608.475983

# %%
dTdz(500)
# Out:
# array(0.004280355257961865)

# %%
import EOS

S = np.empty(z.size)
S_ext = np.empty(z.size)

for i in range(0,z.size):
    S[i] = EOS.S(T[i], P[i], z[i])
    S_ext[i] = EOS.S(ext.T(z[i]), ext.p(z[i]),z[i])

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(z[m:n], S[m:n], c='black')
axes.plot(z[m:n], S_ext[m:n], c='black', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
axes.set_ylabel(r"$ \nabla_\mathrm{ad} $",fontsize=18)
#axes.legend()

fig.savefig("S.png",bbox_inches='tight')
# Out:
# 1.46942e-07 1773.74
# 7.60848e-08 1594.9
# 1.60554e-07 1773.82
# 9.07568e-08 1591.14
# 1.75219e-07 1773.99
# 1.07267e-07 1590.86
# 1.91003e-07 1773.88
# 1.25184e-07 1598.72
# 2.07977e-07 1773.71
# 1.43743e-07 1612.75
# 2.26214e-07 1773.81
# 1.62985e-07 1625.06
# 2.45786e-07 1773.98
# 1.83242e-07 1635.67
# 2.66774e-07 1773.89
# 2.0474e-07 1644.98
# 2.89263e-07 1773.69
# 2.27644e-07 1653.42
# 3.13339e-07 1773.75
# 2.52086e-07 1661.22
# 3.39088e-07 1773.94
# 2.78193e-07 1668.41
# 3.66606e-07 1773.96
# 3.06081e-07 1674.88
# 3.95994e-07 1773.7
# 3.35866e-07 1680.72
# 4.27352e-07 1773.69
# 3.67665e-07 1686.28
# 4.60785e-07 1773.84
# 4.01593e-07 1691.53
# 4.96401e-07 1773.99
# 4.37769e-07 1696.35
# 5.34317e-07 1773.82
# 4.7632e-07 1700.57
# 5.74656e-07 1773.66
# 5.17375e-07 1704.6
# 6.1754e-07 1773.72
# 5.6106e-07 1708.51
# 6.63093e-07 1773.89
# 6.07509e-07 1712.21
# 7.11446e-07 1773.98
# 6.56862e-07 1715.51
# 7.62743e-07 1773.75
# 7.09268e-07 1718.4
# 8.17129e-07 1773.64
# 7.64876e-07 1721.29
# 8.74749e-07 1773.71
# 8.23834e-07 1724.13
# 9.3575e-07 1773.87
# 8.863e-07 1726.82
# 1.00029e-06 1773.96
# 9.52438e-07 1729.19
# 1.06854e-06 1773.74
# 1.02242e-06 1731.22
# 1.14068e-06 1773.61
# 1.09644e-06 1733.3
# 1.21687e-06 1773.66
# 1.17464e-06 1735.39
# 1.29728e-06 1773.81
# 1.25723e-06 1737.43
# 1.38211e-06 1773.94
# 1.34439e-06 1739.24
# 1.47154e-06 1773.82
# 1.43633e-06 1740.67
# 1.56579e-06 1773.61
# 1.53325e-06 1742.13
# 1.66506e-06 1773.59
# 1.63536e-06 1743.69
# 1.76955e-06 1773.7
# 1.74287e-06 1745.27
# 1.87947e-06 1773.86
# 1.85599e-06 1746.73
# 1.99504e-06 1773.92
# 1.97496e-06 1747.88
# 2.1165e-06 1773.71
# 2.10002e-06 1748.84
# 2.2441e-06 1773.55
# 2.23142e-06 1749.95
# 2.37807e-06 1773.56
# 2.36939e-06 1751.14
# 2.51866e-06 1773.69

#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$\ln P$", fontsize=18)
axes.set_ylabel(r"$ \ln T$",fontsize=18)

data = np.concatenate((np.array([lnP]).T, np.array([np.exp(lnT)]).T), axis=1)
np.savetxt('lnT_z_hloubky.dat', data)

fig.savefig("lnT.png",bbox_inches='tight')

# %%
import EOS

delta = np.empty(z.size)
delta_ext = np.empty(z.size)

for i in range(0,z.size):
    delta[i] = EOS.delta(T[i], P[i], z[i])
    delta_ext[i] = EOS.delta(ext.T(z[i]), ext.p(z[i]), z[i])

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(z[m:n], delta[m:n], c='black')
axes.plot(z[m:n], delta_ext[m:n], c='black', linestyle = '-.')
axes.plot(z[m:n], ext.d(z[m:n]), c='red', linestyle = '-.')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
axes.set_ylabel(r"$ \delta $",fontsize=18)
#axes.legend()

fig.savefig("delta.png",bbox_inches='tight')

# %%
import EOS

o = np.empty(z.size)
o_ext = np.empty(z.size)

for i in range(0,z.size):
    o[i] = EOS.opac(T[i], P[i], z[i])
    o_ext[i] = EOS.opac(ext.T(z[i]), ext.p(z[i]), z[i])

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(z[m:n], o[m:n], c='black')
axes.plot(z[m:n], o_ext[m:n], c='black', linestyle = 'dashed')
axes.plot(z[m:n], ext.o(z[m:n]), c='red', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
axes.set_ylabel(r"$ \rho\ (\mathrm{kg.m^{-3}}) $",fontsize=18)
#axes.legend()

fig.savefig("opacita.png",bbox_inches='tight')

# %%
import EOS

U = np.empty(z.size)
U_ext = np.empty(z.size)

for i in range(0,z.size):
    U[i] = EOS.U(T[i], P[i], z[i])
    U_ext[i] = EOS.U(ext.T(z[i]), ext.p(z[i]), z[i])

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(z[m:n], U[m:n], c='black')
axes.plot(z[m:n], U_ext[m:n], c='black', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
axes.set_ylabel(r"$ U $",fontsize=18)
#axes.legend()

fig.savefig("U.png",bbox_inches='tight')

# %%
import EOS

adG = np.empty(z.size)
adG_ext = np.empty(z.size)

for i in range(0,z.size):
    adG[i] = EOS.adG(T[i], P[i])
    adG_ext[i] = EOS.adG(ext.T(z[i]), ext.p(z[i]))

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(z[m:n], adG[m:n], c='black')
axes.plot(z[m:n], adG_ext[m:n], c='black', linestyle = 'dashed')
axes.plot(z[m:n], ext.adG(z[m:n]), c='red', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
axes.set_ylabel(r"$ \nabla_\mathrm{ad} $",fontsize=18)
#axes.legend()

fig.savefig("adG.png",bbox_inches='tight')

# %%
import EOS
import derivatives as d
from scipy.interpolate import UnivariateSpline

rG = np.empty(z.size)
rG_ext = np.empty(z.size)

for i in range(0,z.size):
    rG[i] = EOS.radG(T[i], P[i], z[i])
    rG_ext[i] = EOS.radG(ext.T(z[i]), ext.p(z[i]), z[i])

convG = np.empty(z.size)
convG_ext = np.empty(z.size)

for i in range(0,z.size):
#    convG[i] = d.TDeriv(T[i], P[i], z[i])
    convG_ext[i] = d.TDeriv(ext.T(z[i]), ext.p(z[i]), z[i])

G = np.empty(z.size)
G_ext = np.empty(z.size)

lnP = UnivariateSpline(z, np.log(P), k=3, s=0)
dlnP = lnP.derivative()
lnP_ext = UnivariateSpline(z, np.log(ext.p(z)), k=3, s=0)
dlnP_ext = lnP_ext.derivative()
lnT = UnivariateSpline(z, np.log(T), k=3, s=0)
dlnT = lnT.derivative()
lnT_ext = UnivariateSpline(z, np.log(ext.T(z)), k=3, s=0)
dlnT_ext = lnT_ext.derivative()

G = lambda z: dlnT(z)/dlnP(z)
G_ext = lambda z: dlnT_ext(z)/dlnP_ext(z)

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
#axes.plot(z[m:n], adG[m:n], c='blue', label = 'adG')
#axes.plot(z[m:n], adG_ext[m:n], c='blue', linestyle = 'dashed')
#axes.plot(z[m:n], ext.adG(z[m:n]), c='red', linestyle = '-.')
#axes.plot(z[m:n], rG[m:n], c='red', label = 'radG')
#axes.plot(z[m:n], rG_ext[m:n], c='red', linestyle = 'dashed')
#axes.plot(z[m:n], convG[m:n], c='green', label = 'convG')
#axes.plot(z[m:n], convG_ext[m:n], c='green', linestyle = 'dashed')
axes.plot(z[m:n], G(z[m:n]), c='black', label = 'd(lnT)/d(lnP)')
axes.plot(z[m:n], G_ext(z[m:n]), c='black', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
#axes.set_ylabel(r"$ \nabla_\mathrm{ad} $",fontsize=18)
#axes.legend()

fig.savefig("gradienty.png",bbox_inches='tight')

# %%
import EOS

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(z[m:n], EOS.(T[m:n],P[m:n]), c='black')
axes.plot(z[m:n], EOS.mu(ext.T(z[m:n]),ext.p(z[m:n])), c='black', linestyle='dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
axes.set_ylabel(r"$ x $",fontsize=18)
#axes.legend()

fig.savefig("x.png",bbox_inches='tight')

# %%
lnP_z_povrchu = np.genfromtxt("/home/tom/Documents/skola/bakalarka/python/lnT_z_povrchu.dat", usecols = (0))
lnT_z_povrchu = np.log(np.genfromtxt("/home/tom/Documents/skola/bakalarka/python/lnT_z_povrchu.dat", usecols = (1)))

# %%
fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
#axes.plot(lnP[m:n], lnT[m:n], c='black')
axes.plot(lnP_z_povrchu[m:n], lnT_z_povrchu[m:n], c='black')
#axes.plot(lnP_eul, lnT_eul, c='red')
axes.plot(lnP_ext(z), lnT_ext(z), c='red', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$\ln P$", fontsize=18)
axes.set_ylabel(r"$ \ln T$",fontsize=18)

fig.savefig("lnT_porovnani.png",bbox_inches='tight')

# %%
from EOS import opac
opac(T, P, z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-16fa90864cb6> in <module>()
#       1 from EOS import opac
# ----> 2 opac(T, P, z)
#
# /home/tom/Documents/skola/bakalarka/python/EOS.pyc in opac(T, P, z)
#      44
#      45 def opac(T, P, z):
# ---> 46     opac0 = ext.opac(T, rho(T,P,z), z)
#      47     return opac0[0,0]
#      48
#
# /home/tom/Documents/skola/bakalarka/python/ext_data.pyc in opac(T, rho, z)
#      59 #               print "R  =  "
#      60 #               print R
# ---> 61         log_opac = f(np.log10(T),np.log10(R))
#      62         return 10**log_opac*0.1
#      63 #       return o(z)
#
# /usr/local/lib/python2.7/dist-packages/scipy/interpolate/fitpack2.pyc in __call__(self, x, y, mth, dx, dy, grid)
#     726                 z,ier = dfitpack.bispev(tx,ty,c,kx,ky,x,y)
#     727                 if not ier == 0:
# --> 728                     raise ValueError("Error code returned by bispev: %s" % ier)
#     729         else:
#     730             # standard Numpy broadcasting
#
# ValueError: Error code returned by bispev: 10

# %%
min(T)
# Out:
# 5020.3925981703751

# %%
min(P)
# Out:
# 5822.1539623287326

# %%
ext.M(0)
# Out:
# array(1.987819547254809e+30)
