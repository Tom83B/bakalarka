# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import ext_data as ext
import loadbcg as bcg
from const import *
Z = np.linspace(0, 12.5e6, 500)

# %%
def radg(z):
    return (3./16)*(ext.o(z)*ext.r(z)*ext.H(z)/(sigma*ext.T(z)**4))

def radg2(z):
    return 3*ext.o(z)*ext.p(z)*4e26/(64*np.pi*sigma*G*ext.T(z)**4*2e30)

# %%
T15 = T

# %%
fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(Z[m:n], ext.T(Z[m:n]), c='black', linestyle = 'dashed')
axes.plot(Z[m:n], bcg.T[m:n], c='red', label = 'alpha=1.9')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
#axes.set_ylabel(r"$ \rho\ \mathrm{(kg/m^3)} $",fontsize=18)
axes.legend()

fig.savefig("T.png",bbox_inches='tight')

# %%
p(0)/(r(0)*g(0))
# Out:
# 139046.47027669766

# %%
execfile('loadbcg.py')

# %%
fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=1
n=100
axes.plot(Z[m:n], radg2(Z[m:n]), c='black', linestyle='dashed')
axes.plot(Z[m:n], dlntdlnp[m:n], c='r', linestyle='dashed')
axes.plot(Z[m:n], bcg_dlntdlnp[m:n], c='r')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
#axes.set_ylabel(r"$ \rho\ \mathrm{(kg/m^3)} $",fontsize=18)

fig.savefig("model_radG.png",bbox_inches='tight')

# %%
execfile('background.py')
# Out:
# 0.0 0.0351353863371
# 3.0559755005 0.0351368644483
# 3.0559755005 0.0351368644954
# 6.111951001 0.0351383463435
# 6.111951001 0.0351383463908
# 127.191672623 0.0351970241825
# 127.191672623 0.0351970240746
# 248.271394244 0.0352558489689
# 248.271394244 0.0352558490387
# 369.351115866 0.035314823604
# 369.351115866 0.0353148236766
# 1341.38646059 0.0357937844793
# 1341.38646059 0.0357937867779
# 2313.42180532 0.036282752091
# 2313.42180532 0.0362827507391
# 3285.45715004 0.0367819948728
# 3285.45715004 0.0367819953565
# 4257.49249477 0.0372918524534
# 4257.49249477 0.0372918533432
# 6305.2336732 0.0384020740017
# 6305.2336732 0.0384020778038
# 8352.97485164 0.0395639725836
# 8352.97485164 0.0395639877289
# 10400.7160301 0.0407810407233
# 10400.7160301 0.0407810574753
# 12448.4572085 0.0420570425547
# 12448.4572085 0.0420570570094
# 15813.1573926 0.0442926142977
# 15813.1573926 0.0442926676879
# 19177.8575768 0.0467191935027
# 19177.8575768 0.0467191785554
# ...

# %%
z=np.genfromtxt('gradienty.dat',usecols=(0))
z = z[1::2]
rG=np.genfromtxt('gradienty.dat',usecols=(1))
aG=np.genfromtxt('gradienty.dat',usecols=(2))
cG=np.genfromtxt('gradienty.dat',usecols=(3))

# %%
xi(2,2)
# Out:
# 2 2
# 2.439704486604783

# %%
lnp = np.log(ext.p(z))
dlnp = np.diff(lnp)
lnt = np.log(ext.T(z))
dlnt = np.diff(lnt)
dlntdlnp = dlnt/dlnp

#bcg_lnp = np.log(bcg.P)
#bcg_dlnp = np.diff(bcg_lnp)
#bcg_lnt = np.log(bcg.T)
#bcg_dlnt = np.diff(bcg_lnt)
#bcg_dlntdlnp = bcg_dlnt/bcg_dlnp
# Out:
# -c:5: RuntimeWarning: invalid value encountered in divide

# %%
np.log(2)
# Out:
# 0.69314718055994529

# %%
fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=1
n=300
axes.plot(z[m:n], rG[m:n], c='r')
axes.plot(z[m:n], aG[m:n], c='g')
axes.plot(z[m:n], cG[m:n], c='b')
axes.plot(z[m:n], radg2(z[m:n]), c='r', linestyle = 'dashed')
#axes.plot(Z[m:n], dlntdlnp[m:n], c='b', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
#axes.set_ylabel(r"$ \rho\ \mathrm{(kg/m^3)} $",fontsize=18)

fig.savefig("model_radG.png",bbox_inches='tight')

# %%
dlntdlnp.size
# Out:
# 4999

# %%
delta = (ext.T(Z[:499])/ext.r(Z[:499]))*np.diff(ext.r(Z))/np.diff(ext.T(Z))

# %%
import EOS

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

#axes.plot(Z[0:499], delta[0:499], label='stare')
#axes.plot(Z, rhoArr, label='stare')
#axes.plot(Z[0:499], np.diff(rhoArr), label='stare')
#axes.plot(Z[0:499], np.diff(EOS.mu(T, P)), label='stare')
axes.plot(ext.z[:ext.z.size-1], np.diff(radg2(ext.z)), label='stare')
#axes.plot(np.diff(ext.T(ext.z)), label='stare')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
axes.set_ylabel("$ y\ \mathrm{(\sqrt{T})} $",fontsize=18)
axes.legend()

fig.savefig("diference_gradientu.png",bbox_inches='tight')

# %%
from derivatives import Frad, Fconv

# %%
FradArr = np.empty(Z.size)
FconvArr = np.empty(Z.size)
for i in range(0,Z.size):
    FradArr[i] = Frad(ext.T(Z[i]), ext.p(Z[i]), Z[i])
    FconvArr[i] = Fconv(ext.T(Z[i]), ext.p(Z[i]), Z[i])

# %%
fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=1
n=50
axes.plot(Z[m:n], -FradArr[m:n], c='r')
axes.plot(Z[m:n], -FconvArr[m:n], c='g')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
#axes.set_ylabel(r"$ \rho\ \mathrm{(kg/m^3)} $",fontsize=18)

#fig.savefig("model_radG.png",bbox_inches='tight')

# %%
FradArr.size
# Out:
# 1

# %%
execfile('background.py')
# Out:
# 0.0 0.152326969124 0.371947412587 0.152326969124
# 3.05664418873 0.152331880263 0.371946547816 0.152331880263
# 3.05664418873 0.152331880223 0.371946547777 0.152331880223
# 6.11328837746 0.152336800073 0.371945682951 0.152336800073
# 6.11328837746 0.152336800034 0.371945682913 0.152336800034
# 168.350503316 0.152598641897 0.371899701109 0.152598641897
# 168.350503316 0.152598641727 0.371899700982 0.152598641727
# 330.587718254 0.152862066968 0.37185356449 0.152862066968
# 330.587718254 0.152862066721 0.371853564169 0.152862066721
# 492.824933192 0.153127108178 0.371807271791 0.153127108178
# 492.824933192 0.153127107947 0.371807271458 0.153127107947
# 1445.81518892 0.154716603031 0.371532149272 0.154716603031
# 1445.81518892 0.15471659885 0.371532144879 0.15471659885
# 2398.80544465 0.156363251421 0.371251387036 0.156363251421
# 2398.80544465 0.156363252327 0.371251390619 0.156363252327
# 3351.79570038 0.158068870375 0.37096479064 0.158068870375
# ...

# %%
import EOS

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(Z[m:n], cpArr, c='black')
axes.plot(Z[m:n], ext_cpArr, c='black', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
#axes.set_ylabel(r"$ \rho\ \mathrm{(kg/m^3)} $",fontsize=18)

#fig.savefig("model_radG.png",bbox_inches='tight')

# %%
import EOS

fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(Z[m:n], EOS.x(bcg.T,bcg.P), c='black')
axes.plot(Z[m:n], EOS.x(ext.T(Z),ext.p(Z)), c='black', linestyle = 'dashed')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
#axes.set_ylabel(r"$ \rho\ \mathrm{(kg/m^3)} $",fontsize=18)

#fig.savefig("model_radG.png",bbox_inches='tight')

# %%
import EOS

cpArr = np.empty(500)
ext_cpArr = np.empty(500)
for i in range(0,500):
    cpArr[i] = EOS.cp(bcg.T[i],bcg.P[i])
    ext_cpArr[i] = EOS.cp(ext.T(Z[i]),ext.p(Z[i]))

# %%
ext_cpArr
# Out:
# 0.1226623272578608

# %%
execfile('background.py')
# Out:
# 0.0
# 3.05678931942
# 3.05678931942
# 6.11357863883
# 6.11357863883
# 120.500544091
# 120.500544091
# 234.887509544
# 234.887509544
# 349.274474996
# 349.274474996
# 854.310408787
# 854.310408787
# 1359.34634258
# 1359.34634258
# 1864.38227637
# 1864.38227637
# 3812.20830708
# 3812.20830708
# 2502.7173594
# 2502.7173594
# 1990.62339079
# 1990.62339079
# 2116.86450522
# 2116.86450522
# 2243.10561964
# 2243.10561964
# 2495.58784849
# 2495.58784849
# 2311.10569965
# 2311.10569965
# 2256.70563564
# 2256.70563564
# 2270.30565165
# 2270.30565165
# 2283.90566765
# 2283.90566765
# 2311.10569965
# 2311.10569965
# 2338.30573165
# 2338.30573165
# 2365.50576366
# 2365.50576366
# 2637.50608369
# 2637.50608369
# 2442.08108019
# 2442.08108019
# 2518.65639672
# 2518.65639672
# 2493.26996217
# 2493.26996217
# 2544.45884414
# 2544.45884414
# 2535.77265836
# 2535.77265836
# 2578.27535455
# 2578.27535455
# 2620.77805074
# 2620.77805074
# 2705.78344313
# 2705.78344313
# 2790.78883551
# 2790.78883551
# ...

# %%
fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(Z[m:n], ext.p(Z[m:n]), c='black', linestyle = 'dashed')
axes.plot(Z[m:n], bcg.P[m:n], c='red', label = 'alpha=1.9')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
#axes.set_ylabel(r"$ \rho\ \mathrm{(kg/m^3)} $",fontsize=18)
axes.legend()

fig.savefig("p.png",bbox_inches='tight')

# %%
fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
#axes.plot(Z[m:n], ext.p(Z[m:n]), c='black', linestyle = 'dashed')
axes.plot(Z[m:n-1], np.diff(P[m:n])/(g(Z[m:n-1])*np.diff(Z[m:n])), c='red', label = 'alpha=1.9')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
#axes.set_ylabel(r"$ \rho\ \mathrm{(kg/m^3)} $",fontsize=18)
axes.legend()

fig.savefig("dp.png",bbox_inches='tight')

# %%
import EOS

rhoArr = np.empty(500)
for i in range(0,500):
    rhoArr[i] = EOS.rho(ext.T(Z[i]),ext.p(Z[i]),Z[i])

# %%
fig = plt.figure(figsize=(12,6), dpi=300)

axes = fig.add_axes([0,0,1,1])

m=0
n=500
axes.plot(Z[m:n], ext.r(Z[m:n]), c='black', linestyle = 'dashed', label = 'alpha=1.9')
axes.plot(Z[m:n], rhoArr[m:n], c='red')
#axes.plot(z, ext.r(z), c='black', linestyle='dashed')
axes.set_xlabel("$z\ (\mathrm{m})$", fontsize=18)
#axes.set_ylabel(r"$ \rho\ \mathrm{(kg/m^3)} $",fontsize=18)
#axes.legend()

fig.savefig("rho_modelS.png",bbox_inches='tight')

# %%
import eos

# %%
eos.esac(X, ztab, T[100]*1e-6, rho(T[100], P[100], 0)*1e-3, 7, irad)
# Out:
# array([  3.77863653e-05,   9.31690311e+00,   1.76605591e+03,
#          9.70257507e+02,   8.99435282e-01,   1.90674388e+00,
#          1.25329137e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00], dtype=float32)
